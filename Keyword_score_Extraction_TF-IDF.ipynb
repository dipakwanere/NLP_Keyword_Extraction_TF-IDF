# %% [markdown]
# #### Import Required Libraries ans setup the environment.

# %%
import pandas as pd
import numpy as np
import re
import nltk
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import PorterStemmer

nltk.download("stopwords")
nltk.download("punkt")
import warnings
from sklearn.exceptions import DataConversionWarning
warnings.filterwarnings(action='ignore', category=DataConversionWarning)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dipak\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\dipak\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df = pd.read_excel("C:/Users/dipak/2023/NLP_Keyword_Extraction/Corona_tweets/corona_tweeets.xlsx")

# %%
df
# Out:
#        User_name   Time                      Location  \
# 0              1  43906                        London
# 1              2  43906                            UK
# 2              3  43906                     Vagabonds
# 3              4  43906                           NaN
# 4              5  43906                           NaN
# ...          ...    ...                           ...
# 41152      41153  43935  Wellington City, New Zealand
# 41153      41154  43935                           NaN
# 41154      41155  43935                           NaN
# 41155      41156  43935                           NaN
# 41156      41157  43935  i love you so much || he/him
#
#                                                     text
# 0      @MeNyrbie @Phil_Gahan @Chrisitv https://t.co/i...
# 1      advice Talk to your neighbours family to excha...
# 2      Coronavirus Australia: Woolworths to give elde...
# 3      My food stock is not the only one which is emp...
# ...

# %%
df['text'] = df['text'].astype(str)
from nltk.stem import WordNetLemmatizer
stop_words = stopwords.words("english")
stop_words.extend(['co','http','covid','coronavirus','amp','ha'])

# %%
corpus = []

for i in range(0,len(df)):
    review = re.sub('[^a-zA-Z]', ' ',df['text'][i])
    review = review.lower()
    review = review.split()
    ps = WordNetLemmatizer()
    review =[ps.lemmatize(word) for word in review]
    review = [word for word in review if not word in set(stop_words)]
    review = ' '.join(review)
    corpus.append(review)

# %%
corpus
# Out:
# ['menyrbie phil gahan chrisitv ifz fan pa xx ghgfzcc nlzdxno',
#  'advice talk neighbour family exchange phone number create contact list phone number neighbour school employer chemist gp set online shopping account po adequate supply regular med order',
#  'australia woolworth give elderly disabled dedicated shopping hour amid outbreak binca vp p',
#  'food stock one empty x x x x please panic enough food everyone take need x x stay calm stay safe x x x x france confinement confinementotal confinementgeneral zrlg z j',
#  'ready go supermarket outbreak x x x x paranoid food stock litteraly empty serious thing please panic cause shortage x x x x coronavirusfrance restezchezvous stayathome confinement usmualq n',
#  'news region first confirmed case came sullivan county last week people flocked area store purchase cleaning supply hand sanitizer food toilet paper good tim dodson report cfxch lu',
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
cv = TfidfVectorizer(ngram_range=(1,1))
corpus1 = cv.fit_transform(corpus)
avg = corpus1.mean(axis=0)
avg = pd.DataFrame(avg, columns=cv.get_feature_names())
avg=avg.T
avg = avg.rename(columns={0:'score'})
avg['word'] = avg.index
avg=avg.sort_values('score',ascending=False)
#avg = avg[:50]
# Out:
# C:\Users\dipak\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
avg
# Out:
#                 score         word
# store        0.020394        store
# price        0.020040        price
# supermarket  0.019263  supermarket
# grocery      0.018058      grocery
# food         0.018040         food
# people       0.015029       people
# consumer     0.013871     consumer
# shopping     0.011505     shopping
# online       0.011048       online
# need         0.010132         need
# pandemic     0.010057     pandemic
# worker       0.009885       worker
# time         0.009867         time
# get          0.009620          get
# hand         0.008867         hand
# panic        0.008785        panic
# go           0.008637           go
# sanitizer    0.008097    sanitizer
# home         0.008062         home
# like         0.007933         like
# demand       0.007657       demand
# wa           0.007570           wa
# stock        0.007417        stock
# help         0.007397         help
# one          0.007143          one
# going        0.007128        going
# ...

# %%
cv_bigram = TfidfVectorizer(ngram_range=(3,3)) # max_features=100
corpus1_bigram = cv_bigram.fit_transform(corpus)
avg_bigram = corpus1_bigram.mean(axis=0)
avg_bigram = pd.DataFrame(avg_bigram, columns=cv_bigram.get_feature_names())
avg_bigram = avg_bigram.T
avg_bigram = avg_bigram.rename(columns={0:'score'})
avg_bigram['word'] = avg_bigram.index
avg_bigram = avg_bigram.sort_values('score',ascending=False)

# %%
avg_bigram
# Out:
#                                score                        word
# grocery store worker        0.001717        grocery store worker
# go grocery store            0.001199            go grocery store
# grocery store employee      0.001071      grocery store employee
# going grocery store         0.000885         going grocery store
# local grocery store         0.000708         local grocery store
# ...                              ...                         ...
# note next ballot            0.000003            note next ballot
# city lahore kanal           0.000003           city lahore kanal
# lahore kanal lac            0.000003            lahore kanal lac
# look affecting witqx        0.000003        look affecting witqx
# ohiolockdown grocery store  0.000002  ohiolockdown grocery store
#
# [574113 rows x 2 columns]

# %%
cv_trigram = TfidfVectorizer(ngram_range=(2,2)) # max_features=100
corpus1_trigram = cv_trigram.fit_transform(corpus)
avg_trigram = corpus1_trigram.mean(axis=0)
avg_trigram = pd.DataFrame(avg_trigram, columns=cv_trigram.get_feature_names())
avg_trigram = avg_trigram.T
avg_trigram = avg_trigram.rename(columns={0:'score'})
avg_trigram['word'] = avg_trigram.index
avg_trigram = avg_trigram.sort_values('score',ascending=False)

# %%
avg_trigram
# Out:
#                                    score                            word
# grocery store                   0.010410                   grocery store
# hand sanitizer                  0.004233                  hand sanitizer
# online shopping                 0.004023                 online shopping
# toilet paper                    0.003727                    toilet paper
# panic buying                    0.003258                    panic buying
# ...                                  ...                             ...
# pandemic coronavirusinpakistan  0.000003  pandemic coronavirusinpakistan
# april mian                      0.000003                      april mian
# lahore residential              0.000003              lahore residential
# ballot held                     0.000003                     ballot held
# ohiolockdown grocery            0.000003            ohiolockdown grocery
#
# [437336 rows x 2 columns]

# %%
cv_fourgram = TfidfVectorizer(ngram_range=(4,4)) # max_features=100
corpus1_fourgram = cv_fourgram.fit_transform(corpus)
avg_fourgram = corpus1_fourgram.mean(axis=0)
avg_fourgram = pd.DataFrame(avg_fourgram, columns=cv_fourgram.get_feature_names())
avg_fourgram = avg_fourgram.T
avg_fourgram = avg_fourgram.rename(columns={0:'score'})
avg_fourgram['word'] = avg_fourgram.index
avg_fourgram = avg_fourgram.sort_values('score',ascending=False)

# %%
avg_fourgram
# Out:
#                                                        score  \
# sanitizer italy wuhan grocery                       0.000258
# grocery worker beginning die                        0.000249
# toilet paper hand sanitizer                         0.000225
# panicshopping panicbuyinguk coronavirusupdate s...  0.000206
# stoppanicbuying panicshopping panicbuyinguk cor...  0.000206
# ...                                                      ...
# amazon demand online grocery                        0.000004
# surpassing amazon demand online                     0.000004
# downloads sur su luofp                              0.000004
# buying look affecting witqx                         0.000003
# ohiolockdown grocery store closing                  0.000002
#
#                                                                                                  word
# sanitizer italy wuhan grocery                                           sanitizer italy wuhan grocery
# ...

# %%
cv_figram = TfidfVectorizer(ngram_range=(1,5)) # max_features=100
corpus1_figram = cv_figram.fit_transform(corpus)
avg_figram = corpus1_figram.mean(axis=0)
avg_figram = pd.DataFrame(avg_figram, columns=cv_figram.get_feature_names())
avg_figram = avg_figram.T
avg_figram = avg_figram.rename(columns={0:'score'})
avg_figram['word'] = avg_figram.index
avg_figram = avg_figram.sort_values('score',ascending=False)

# %%
avg_figram
# Out:
#                                               score  \
# price                                      0.006844
# store                                      0.006588
# supermarket                                0.006394
# grocery                                    0.005849
# food                                       0.005783
# ...                                             ...
# pandemic coronavirusinpakistan fvtdvsaseb  0.000002
# ohiolockdown grocery store                 0.000001
# ohiolockdown grocery store closing         0.000001
# ohiolockdown grocery                       0.000001
# ohiolockdown grocery store closing stop    0.000001
#
#                                                                                 word
# price                                                                          price
# store                                                                          store
# ...

# %%
unigrams_list = avg['word'].tolist()
bigrams_list = avg_bigram['word'].tolist()

def convert(lst):
    return ([item.split() for item in lst])

bigrams_split = convert(bigrams_list)

check = pd.DataFrame(columns=['topic','subtopic'])

for i in unigrams_list:
    #print(i)
    counter=0
    for j in bigrams_split:
        if counter<5 and (i==j[0] or i==j[1] or i==j[2]):
            bigram_words = ' '.join(j)
            check = pd.concat([check,pd.concat([pd.Series(i,name='topic'),pd.Series(bigram_words,name='subtopic')],axis=1)],axis=0)
            counter = counter+1
            
check_new = check.groupby(['topic'], as_index=False, sort=False).agg({'subtopic':', '.join})

# %%
check_new
# Out:
#           topic                                           subtopic
# 0         store  grocery store worker, go grocery store, grocer...
# 1         price  low oil price, crude oil price, falling oil pr...
# 2   supermarket  empty supermarket shelf, supermarket shelf emp...
# 3       grocery  grocery store worker, go grocery store, grocer...
# 4          food  food supply chain, panic buying food, local fo...
# 5        people  people panic buying, people grocery store, gro...
# 6      consumer  consumer small business, change consumer behav...
# 7      shopping  online grocery shopping, online shopping behav...
# 8        online  online grocery shopping, online shopping behav...
# 9          need  need panic buy, grocery store need, need toile...
# 10     pandemic  grocery store pandemic, price amid pandemic, f...
# 11       worker  grocery store worker, worker grocery store, he...
# 12         time  grocery store time, time online shopping, supe...
# ...

# %%
# Text data as a string

text_data = "The first few times, it was because I was a bridesmaid at my sister or friends weddings and all of us got in the spirit of imagining our own special day, says Wallace, a stockbroker in San Francisco."

# %%
# Tokenize sentences
sentences = sent_tokenize(text_data)

# Initialize stemmer
stemmer = PorterStemmer()

# Define stop words
stop_words = set(stopwords.words("english"))

# Initialize an empty list to store preprocessed sentences
preprocessed_sentences = []

# Iterate through each sentence
for sentence in sentences:
    # Tokenize words in sentence
    words = word_tokenize(sentence)
    
    # Remove stop words
    filtered_words = [word for word in words if word.lower() not in stop_words]
    
    # Stem words
    #stemmed_words = [stemmer.stem(word) for word in filtered_words]
    
    # Join stemmed words to form a preprocessed sentence
    preprocessed_sentence = " ".join(stemmed_words)
    
    # Append preprocessed sentence to the list
    preprocessed_sentences.append(preprocessed_sentence)

# %%
# Instantiate TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform preprocessed text data
tfidf_matrix = tfidf_vectorizer.fit_transform(preprocessed_sentences)

# Extract feature names (keywords)
keywords = tfidf_vectorizer.get_feature_names()

# Print keywords and their TF-IDF scores
for i in range(len(keywords)):
    print(keywords[i], tfidf_matrix[0, i])
# Out:
# choic 0.3779644730092272
# major 0.3779644730092272
# mani 0.3779644730092272
# remain 0.3779644730092272
# singl 0.3779644730092272
# vast 0.3779644730092272
# women 0.3779644730092272
